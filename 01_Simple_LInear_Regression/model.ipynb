# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
plt.scatter(df['Weight'],df['Height'])
plt.xlabel("Weight")
plt.ylabel("Height")
plt.show()

# %%
X=df[['Weight']]
y=df['Height']

# %%
X.head()
# Out:
#    Weight
# 0      45
# 1      58
# 2      48
# 3      60
# 4      70

# %%
y.head()
# Out:
# 0    120
# 1    135
# 2    123
# 3    145
# 4    160
# Name: Height, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=42)

# %%
X.shape
# Out:
# (23, 1)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((18, 1), (5, 1), (18,), (5,))

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 1.73689094],
#        [-0.92026952],
#        [ 1.4542143 ],
#        [ 0.21043706],
#        [-1.48562281],
#        [ 1.17153765],
#        [-1.6552288 ],
#        [-0.80719886],
#        [-0.24184557],
#        [ 0.0973664 ],
#        [-1.37255215],
#        [-1.03334018],
#        [-0.12877492],
#        [ 0.88886101],
#        [ 0.43657837],
#        [ 0.60618436],
#        [ 0.71925502],
#        [ 0.32350772]])

# %%
X_test
# Out:
# array([[ 0.21043706],
#        [ 0.21043706],
#        [-1.6552288 ],
#        [ 1.17153765],
#        [-0.52452222]])

# %%
plt.scatter(X_train, y_train)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_  ## Slope of the weight is defined by this
# Out:
# array([17.03440872])

# %%
regressor.intercept_
# Out:
# np.float64(157.5)

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, regressor.predict(X_train), 'g')

# %%
y_pred_test=regressor.predict(X_test)

# %%
y_pred_test, y_test
# Out:
# (array([161.08467086, 161.08467086, 129.3041561 , 177.45645118,
#         148.56507414]),
#  15    177
#  9     170
#  0     120
#  8     182
#  17    159
#  Name: Height, dtype: int64)

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred_test, 'g')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mse=mean_squared_error(y_test, y_pred_test)
mae=mean_absolute_error(y_test, y_pred_test)
rmse=np.sqrt(mse)
print("MSE:", mse)
print("MAE:", mae)
print("RMSE", rmse)
# Out:
# MSE: 109.77592599051664
# MAE: 9.822657814519232
# RMSE 10.477400726827081

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test, y_pred_test)

# %%
print("R2 Score:", score)
# Out:
# R2 Score: 0.776986986042344

# %%
adjusted_r2_score= 1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

# %%
print("Adjusted R2 Value:", adjusted_r2_score)
# Out:
# Adjusted R2 Value: 0.7026493147231252

# %%
regressor
# Out:
# LinearRegression()

# %%
# Prediction for new data

scaled_weight=scaler.transform([[80]])
scaled_weight
# Out:
# c:\Users\jhash\Downloads\ML-Algorithms-Practice\mlops-practice\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[0.32350772]])

# %%
print("Height prediction for 80 kg weight:", regressor.predict([scaled_weight[0]]))
# Out:
# Height prediction for 80 kg weight: [163.01076266]

# %%
plt.scatter(y_test, y_pred_test)

# %%
residuals=y_test, y_pred_test
residuals
# Out:
# (15    177
#  9     170
#  0     120
#  8     182
#  17    159
#  Name: Height, dtype: int64,
#  array([161.08467086, 161.08467086, 129.3041561 , 177.45645118,
#         148.56507414]))

# %%
sns.displot(residuals, kde=True, color='orange')
